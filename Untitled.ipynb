# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import linear_model

# %%
df = pd.read_csv("RawData.csv")
df
# Out:
#               ID Case Number                    Date                   Block  \
# 0       11284443    JB222786  01/01/2018 12:00:00 AM      012XX S FEDERAL ST
# 1       11192240    JB100098  01/01/2018 12:00:00 AM  105XX S SACRAMENTO AVE
# 2       11192265    JB100106  01/01/2018 12:00:00 AM         006XX E 37TH PL
# 3       11193239    JB101330  01/01/2018 12:00:00 AM         043XX W 18TH PL
# 4       11194228    JB102808  01/01/2018 12:00:00 AM         006XX W 18TH ST
# ...          ...         ...                     ...                     ...
# 404402  12868530    JF445699  10/22/2022 11:30:00 PM     057XX W NEWPORT AVE
# 404403  12868148    JF445230  10/22/2022 11:30:00 PM         018XX W 58TH ST
# 404404  12868175    JF445261  10/22/2022 11:45:00 PM  013XX E HYDE PARK BLVD
# 404405  12868637    JF445836  10/22/2022 11:45:00 PM      028XX S VERNON AVE
# 404406  12868497    JF445684  10/22/2022 11:50:00 PM     008XX W SHERIDAN RD
#
# ...

# %%
df.drop(['Case Number','ID','IUCR','Location Description','Arrest', 'Domestic'], axis=1, inplace = True)

# %%
df
# Out:
#                           Date                   Block         Primary Type  \
# 0       01/01/2018 12:00:00 AM      012XX S FEDERAL ST              ASSAULT
# 1       01/01/2018 12:00:00 AM  105XX S SACRAMENTO AVE      CRIMINAL DAMAGE
# 2       01/01/2018 12:00:00 AM         006XX E 37TH PL  MOTOR VEHICLE THEFT
# 3       01/01/2018 12:00:00 AM         043XX W 18TH PL      CRIMINAL DAMAGE
# 4       01/01/2018 12:00:00 AM         006XX W 18TH ST  MOTOR VEHICLE THEFT
# ...                        ...                     ...                  ...
# 404402  10/22/2022 11:30:00 PM     057XX W NEWPORT AVE  MOTOR VEHICLE THEFT
# 404403  10/22/2022 11:30:00 PM         018XX W 58TH ST              ASSAULT
# 404404  10/22/2022 11:45:00 PM  013XX E HYDE PARK BLVD              ASSAULT
# 404405  10/22/2022 11:45:00 PM      028XX S VERNON AVE  MOTOR VEHICLE THEFT
# 404406  10/22/2022 11:50:00 PM     008XX W SHERIDAN RD              ASSAULT
#
# ...

# %%
df.drop(['Beat','District','Ward','Community Area','FBI Code','X Coordinate','Y Coordinate'], axis=1, inplace = True)

# %%
df
# Out:
#                           Date                   Block         Primary Type  \
# 0       01/01/2018 12:00:00 AM      012XX S FEDERAL ST              ASSAULT
# 1       01/01/2018 12:00:00 AM  105XX S SACRAMENTO AVE      CRIMINAL DAMAGE
# 2       01/01/2018 12:00:00 AM         006XX E 37TH PL  MOTOR VEHICLE THEFT
# 3       01/01/2018 12:00:00 AM         043XX W 18TH PL      CRIMINAL DAMAGE
# 4       01/01/2018 12:00:00 AM         006XX W 18TH ST  MOTOR VEHICLE THEFT
# ...                        ...                     ...                  ...
# 404402  10/22/2022 11:30:00 PM     057XX W NEWPORT AVE  MOTOR VEHICLE THEFT
# 404403  10/22/2022 11:30:00 PM         018XX W 58TH ST              ASSAULT
# 404404  10/22/2022 11:45:00 PM  013XX E HYDE PARK BLVD              ASSAULT
# 404405  10/22/2022 11:45:00 PM      028XX S VERNON AVE  MOTOR VEHICLE THEFT
# 404406  10/22/2022 11:50:00 PM     008XX W SHERIDAN RD              ASSAULT
#
# ...

# %%
df.drop(['Updated On','Location'], axis=1, inplace = True)

# %%
df
# Out:
#                           Date                   Block         Primary Type  \
# 0       01/01/2018 12:00:00 AM      012XX S FEDERAL ST              ASSAULT
# 1       01/01/2018 12:00:00 AM  105XX S SACRAMENTO AVE      CRIMINAL DAMAGE
# 2       01/01/2018 12:00:00 AM         006XX E 37TH PL  MOTOR VEHICLE THEFT
# 3       01/01/2018 12:00:00 AM         043XX W 18TH PL      CRIMINAL DAMAGE
# 4       01/01/2018 12:00:00 AM         006XX W 18TH ST  MOTOR VEHICLE THEFT
# ...                        ...                     ...                  ...
# 404402  10/22/2022 11:30:00 PM     057XX W NEWPORT AVE  MOTOR VEHICLE THEFT
# 404403  10/22/2022 11:30:00 PM         018XX W 58TH ST              ASSAULT
# 404404  10/22/2022 11:45:00 PM  013XX E HYDE PARK BLVD              ASSAULT
# 404405  10/22/2022 11:45:00 PM      028XX S VERNON AVE  MOTOR VEHICLE THEFT
# 404406  10/22/2022 11:50:00 PM     008XX W SHERIDAN RD              ASSAULT
#
# ...

# %%
df['Dates'] = pd.to_datetime(df['Date']).dt.date
df['Time'] = pd.to_datetime(df['Date']).dt.time
df
# Out:
#                           Date                   Block         Primary Type  \
# 0       01/01/2018 12:00:00 AM      012XX S FEDERAL ST              ASSAULT
# 1       01/01/2018 12:00:00 AM  105XX S SACRAMENTO AVE      CRIMINAL DAMAGE
# 2       01/01/2018 12:00:00 AM         006XX E 37TH PL  MOTOR VEHICLE THEFT
# 3       01/01/2018 12:00:00 AM         043XX W 18TH PL      CRIMINAL DAMAGE
# 4       01/01/2018 12:00:00 AM         006XX W 18TH ST  MOTOR VEHICLE THEFT
# ...                        ...                     ...                  ...
# 404402  10/22/2022 11:30:00 PM     057XX W NEWPORT AVE  MOTOR VEHICLE THEFT
# 404403  10/22/2022 11:30:00 PM         018XX W 58TH ST              ASSAULT
# 404404  10/22/2022 11:45:00 PM  013XX E HYDE PARK BLVD              ASSAULT
# 404405  10/22/2022 11:45:00 PM      028XX S VERNON AVE  MOTOR VEHICLE THEFT
# 404406  10/22/2022 11:50:00 PM     008XX W SHERIDAN RD              ASSAULT
#
# ...

# %%
df.drop(df[(df['Year'] < 2020)].index, inplace=True)

# %%
df
# Out:
#                           Date                   Block         Primary Type  \
# 182192  01/01/2020 12:00:00 AM    020XX N LOCKWOOD AVE              ASSAULT
# 182193  01/01/2020 12:00:00 AM    013XX S KILBOURN AVE              ASSAULT
# 182194  01/01/2020 12:00:00 AM    082XX S MARYLAND AVE             BURGLARY
# 182195  01/01/2020 12:00:00 AM         040XX W 21ST ST      CRIMINAL DAMAGE
# 182196  01/01/2020 12:00:00 AM      057XX S PAULINA ST             BURGLARY
# ...                        ...                     ...                  ...
# 404402  10/22/2022 11:30:00 PM     057XX W NEWPORT AVE  MOTOR VEHICLE THEFT
# 404403  10/22/2022 11:30:00 PM         018XX W 58TH ST              ASSAULT
# 404404  10/22/2022 11:45:00 PM  013XX E HYDE PARK BLVD              ASSAULT
# 404405  10/22/2022 11:45:00 PM      028XX S VERNON AVE  MOTOR VEHICLE THEFT
# 404406  10/22/2022 11:50:00 PM     008XX W SHERIDAN RD              ASSAULT
#
# ...

# %%
df['Area'] = df['Block'].str[7:]

# %%
df
# Out:
#                           Date                   Block         Primary Type  \
# 182192  01/01/2020 12:00:00 AM    020XX N LOCKWOOD AVE              ASSAULT
# 182193  01/01/2020 12:00:00 AM    013XX S KILBOURN AVE              ASSAULT
# 182194  01/01/2020 12:00:00 AM    082XX S MARYLAND AVE             BURGLARY
# 182195  01/01/2020 12:00:00 AM         040XX W 21ST ST      CRIMINAL DAMAGE
# 182196  01/01/2020 12:00:00 AM      057XX S PAULINA ST             BURGLARY
# ...                        ...                     ...                  ...
# 404402  10/22/2022 11:30:00 PM     057XX W NEWPORT AVE  MOTOR VEHICLE THEFT
# 404403  10/22/2022 11:30:00 PM         018XX W 58TH ST              ASSAULT
# 404404  10/22/2022 11:45:00 PM  013XX E HYDE PARK BLVD              ASSAULT
# 404405  10/22/2022 11:45:00 PM      028XX S VERNON AVE  MOTOR VEHICLE THEFT
# 404406  10/22/2022 11:50:00 PM     008XX W SHERIDAN RD              ASSAULT
#
# ...

# %%
df.drop(['Block'], axis=1, inplace = True)

# %%
df
# Out:
#                           Date         Primary Type  \
# 182192  01/01/2020 12:00:00 AM              ASSAULT
# 182193  01/01/2020 12:00:00 AM              ASSAULT
# 182194  01/01/2020 12:00:00 AM             BURGLARY
# 182195  01/01/2020 12:00:00 AM      CRIMINAL DAMAGE
# 182196  01/01/2020 12:00:00 AM             BURGLARY
# ...                        ...                  ...
# 404402  10/22/2022 11:30:00 PM  MOTOR VEHICLE THEFT
# 404403  10/22/2022 11:30:00 PM              ASSAULT
# 404404  10/22/2022 11:45:00 PM              ASSAULT
# 404405  10/22/2022 11:45:00 PM  MOTOR VEHICLE THEFT
# 404406  10/22/2022 11:50:00 PM              ASSAULT
#
#                           Description  Year   Latitude  Longitude       Dates  \
# 182192                         SIMPLE  2020  41.917922 -87.758419  2020-01-01
# 182193         AGGRAVATED PO: HANDGUN  2020  41.863700 -87.737326  2020-01-01
# 182194                 FORCIBLE ENTRY  2020  41.745354 -87.603799  2020-01-01
# ...

# %%
plt.scatter(df['Latitude'],df['Longitude'],color = 'red',marker = '.')

# %%
#--------Because of that one corner value the mapping of points is messy------------------------------------------------------

# %%
df['Latitude'].min()
# Out:
# 36.619446395

# %%
df.drop(df[(df['Latitude'] < 40)].index, inplace=True)

# %%
plt.scatter(df['Latitude'],df['Longitude'],color = 'red',marker = '.')

# %%
#------------------Now we get a clearer image of latitudes and longitudes-----------------------------------------------------

# %%
df.to_csv('file1.csv')
